# %%
#document similarity

application : plagerism detection

#1.cosine similarity
compare document vectors angles
value between 0 and 1
if 1 means 100% similar

#2.jaccard similarity
used to compare two sets 
used for binary features

#ugredient distance
how far points are in straight line


#model Testing

#cross validation
used for testing 

#overfittin
poor perform on text data

#under fitting
model simple , poor performance on both text and training data


#classificatioin matrices
accuracy 
precision
recall
f1 score (hormonic mean between precision and recall)

#regression matrics
mean absolute error
mean square error
root mean square 
r square


#data set
model also depends same as algorithm as on data
#balance data
#imbalance data
to imbalance see we use graphs

approaches to balencs data
1.over sampling (random over sampling, adoptly over sampling , synthatic minortiy over sampling, adobtive)
2.under sampling (reduce majority) (random , cluster , algorithm)
3.can do both over and under

can do on video and audio
